# %% [markdown]
# # Forecasting Project
#
# Preview the synthetic operations time series and baseline forecast.

# %%
from pathlib import Path
    import pandas as pd

    data_path = Path("..") / "data" / "sample_synthetic_data.csv"
    df = pd.read_csv(data_path)
    display(df.head())
    display(df.describe(include="all").transpose().head(12))
    display(df[["actual_contacts", "baseline_forecast"]].tail(10))
